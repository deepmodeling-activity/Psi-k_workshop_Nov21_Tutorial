# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import gamma, norm

# %%
lcurve=np.loadtxt("train_data/train/lcurve.out")

# %%
plt.figure(figsize=(12, 9), facecolor='white')

plt.yscale("log")
plt.plot(lcurve[:, 0], lcurve[:, 1], label="Total MSE, validation", color = "blue")
plt.plot(lcurve[:, 0], lcurve[:, 2], label="Total MSE, training", color = "red")


# plt.plot(lcurve[:, 0], lcurve[:, 3], label="Energy MSE, validation", color = "purple")
# plt.plot(lcurve[:, 0], lcurve[:, 4], label="Energy MSE, training", color = "green")

# plt.plot(lcurve[:, 0], lcurve[:, 5], label="Force MSE, validation", color = "black")
# plt.plot(lcurve[:, 0], lcurve[:, 6], label="Force MSE, training", color = "black")

plt.xlabel("Step", fontsize=16)
plt.ylabel("", fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
plt.show()
